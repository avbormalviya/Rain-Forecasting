# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from zenml.client import Client

# %%
client = Client()
pipeline = client.get_pipeline("training_pipeline")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:2                                                                                    │
# │                                                                                                  │
# │   1 client = Client()                                                                            │
# │ ❱ 2 pipeline = client.get_pipeline("training_pipeline")                                          │
# │   3                                                                                              │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\client_lazy_loader.py:213 in  │
# │ _inner                                                                                           │
# │                                                                                                  │
# │   210 │   │   │   │   │   with contextlib.suppress(ValueError):                                  │
# │   211 │   │   │   │   │   │   kwargs[k] = ClientLazyLoader(**v).evaluate()                       │
# │   212 │   │   │                                                                                  │
# │ ❱ 213 │   │   │   return func(*args_, **kwargs)                                                  │
# │   214 │   │                                                                                      │
# │   215 │   │   return _inner                                                                      │
# │   216                                                                                            │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\client.py:2810 in             │
# │ get_pipeline                                                                                     │
# │                                                                                                  │
# │   2807 │   │   │   The pipeline.                                                                 │
# │   2808 │   │   """                                                                               │
# │   2809 │   │   return self._get_entity_by_id_or_name_or_prefix(                                  │
# │ ❱ 2810 │   │   │   get_method=self.zen_store.get_pipeline,                                       │
# │   2811 │   │   │   list_method=self.list_pipelines,                                              │
# │   2812 │   │   │   name_id_or_prefix=name_id_or_prefix,                                          │
# │   2813 │   │   │   project=project,                                                              │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\client.py:672 in zen_store    │
# │                                                                                                  │
# │    669 │   │   Returns:                                                                          │
# │    670 │   │   │   The global zen store.                                                         │
# │    671 │   │   """                                                                               │
# │ ❱  672 │   │   return GlobalConfiguration().zen_store                                            │
# │    673 │                                                                                         │
# │    674 │   @property                                                                             │
# │    675 │   def root(self) -> Optional[Path]:                                                     │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\config\global_config.py:233   │
# │ in __custom_getattribute__                                                                       │
# │                                                                                                  │
# │   230 │   │   Returns:                                                                           │
# │   231 │   │   │   The attribute value.                                                           │
# │   232 │   │   """                                                                                │
# │ ❱ 233 │   │   value = super().__getattribute__(key)                                              │
# │   234 │   │   if key.startswith("_") or key not in type(self).model_fields:                      │
# │   235 │   │   │   return value                                                                   │
# │   236                                                                                            │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\config\global_config.py:753   │
# │ in zen_store                                                                                     │
# │                                                                                                  │
# │   750 │   │   │   The current zen store.                                                         │
# │   751 │   │   """                                                                                │
# │   752 │   │   if self._zen_store is None:                                                        │
# │ ❱ 753 │   │   │   self._configure_store(self.store_configuration)                                │
# │   754 │   │   assert self._zen_store is not None                                                 │
# │   755 │   │                                                                                      │
# │   756 │   │   return self._zen_store                                                             │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\config\global_config.py:372   │
# │ in _configure_store                                                                              │
# │                                                                                                  │
# │   369 │   │                                                                                      │
# │   370 │   │   # TODO: Revisit the flow regarding the registration of the default                 │
# │   371 │   │   #  entities once the analytics v1 is removed.                                      │
# │ ❱ 372 │   │   store = BaseZenStore.create_store(config, True, **kwargs)                          │
# │   373 │   │                                                                                      │
# │   374 │   │   logger.debug(f"Configuring the global store to {store.config}")                    │
# │   375 │   │   self.store = store.config                                                          │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\zen_stores\base_zen_store.py: │
# │ 238 in create_store                                                                              │
# │                                                                                                  │
# │   235 │   │   Returns:                                                                           │
# │   236 │   │   │   The initialized store.                                                         │
# │   237 │   │   """                                                                                │
# │ ❱ 238 │   │   store_class = BaseZenStore.get_store_class(config.type)                            │
# │   239 │   │   store = store_class(                                                               │
# │   240 │   │   │   config=config,                                                                 │
# │   241 │   │   │   skip_default_registrations=skip_default_registrations,                         │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\zen_stores\base_zen_store.py: │
# │ 165 in get_store_class                                                                           │
# │                                                                                                  │
# │   162 │   │   │   │                                                                              │
# │   163 │   │   │   │   return RBACSqlZenStore                                                     │
# │   164 │   │   │   else:                                                                          │
# │ ❱ 165 │   │   │   │   from zenml.zen_stores.sql_zen_store import SqlZenStore                     │
# │   166 │   │   │   │                                                                              │
# │   167 │   │   │   │   return SqlZenStore                                                         │
# │   168 │   │   elif store_type == StoreType.REST:                                                 │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\zen_stores\sql_zen_store.py:2 │
# │ 1 in <module>                                                                                    │
# │                                                                                                  │
# │      18 from zenml.dispatcher import EventDispatcher                                             │
# │      19 from zenml.models.v2.core.step_run import StepHeartbeatResponse                          │
# │      20 from zenml.utils.pydantic_utils import before_validator_handler                          │
# │ ❱    21 from zenml.zen_stores.migrations.backup.base import BaseDatabaseBackupEngine             │
# │      22 from zenml.zen_stores.resource_pools.store_interface import (                            │
# │      23 │   ResourcePoolsSQLStoreInterface,                                                      │
# │      24 )                                                                                        │
# │                                                                                                  │
# │ C:\Users\Asus\AppData\Roaming\Python\Python312\site-packages\zenml\zen_stores\migrations\backup\ │
# │ base.py:25 in <module>                                                                           │
# │                                                                                                  │
# │    22 │   cast,                                                                                  │
# │    23 )                                                                                          │
# │    24                                                                                            │
# │ ❱  25 import pymysql                                                                             │
# │    26 from sqlalchemy import text                                                                │
# │    27 from sqlalchemy.engine import Engine                                                       │
# │    28 from sqlalchemy.exc import (                                                               │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ModuleNotFoundError: No module named 'pymysql'
